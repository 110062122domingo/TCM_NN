# %% [markdown]
# # Neuron Network Model for Tradition Chinese Medicine Prescription Training
#
#
# ## About this Notebook
#
# This notebook is a template to train a neuron network model for tradition chinese medicine prescription.
#
# This notebook provide a convenient way to adjust model hyperparameters, as well as saving the performance evaluation metrics of each medicine, and the trained model in .pb format.
#
# ## Result Saving
#
# Performance metrics including the following will in saved in csv format:
#
# - f1-score
# - precision
# - recall
# - True Positive counts (TP)
# - False Positive counts (FP)
# - True Negative counts (TN)
# - False Negative counts (FN)
#
# ## Model Saving
#
# This notebook also save the trained model in .pb format by `tensorflow.keras.Model.save`
#
# ## How to Use
#
# ### Package Requirements
# To run this noteboook, install packages in `requirements.txt` first.
#
# ### Prepare Data
#
# Prepare training data in csv format, follow the format as "simplified_data/simplified_data.csv".
#
# Adjust path to the data in `file_name` in section **[0. Global Variables]**
#
# the default data path is "simplified_data/simplified_data.csv"
#
# another file named `data_grouped_symptom.csv` is an alternative source data, which only contains symptoms as features (features that are not symptoms, such as body status are excluded).
#
# Run the notebook by pressing "Run All".
#
# ### Adjusting Parameter
#
# Parameters can be adjusted in section **[0. Global Variables]**
#
# To tune the dense layers, optimizer, activation function and loss function of the model, adjust in section **[5. Build Model]**

# %% [markdown]
# # 0. Global Variables

# %%
# Remove the entire column related to a specific medicine if its occurrence is below the defined threshold.
# In the given dataset, setting this threshold to 250 would retain columns for only the top 10 most frequently used medicines.
DeleteMedThreshold = 0

# Determine the number of medicines to be trained as output
# The total number of medicine in the default data set is 102
NumMedTrain = 102

# Decide whether to enhance accuracy by utilizing class weights
# If set to True, the inversly proportional class weights will be applied to the loss function
UseClassWeight = True

# Decide learning_rate, this will be used in the Adam Optimizer 
LearningRate = 0.005

# Model num, this string will be the folder name where the result of the model will be saved
ModelNum = "[16]_0_UseWeight"

# Path to source data for training (must be in csv format)
file_name = "./simplified_data/simplified_data.csv"

# %% [markdown]
# # 1. Import module

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import statistics
import csv
from tabulate import tabulate
import matplotlib.pyplot as plt

# Importing TensorFlow for deep learning
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout
from keras.callbacks import EarlyStopping, LambdaCallback
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy

# Importing scikit-learn for data preprocessing and utilities
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils.class_weight import compute_sample_weight

# Importing custom utility functions
from utility_file import my_utilities as myutil
from utility_file import load_data

# %% [markdown]
# # 2. Load Data
# Load the data using the custom module "load_data"

# %%
# Load data for training a model, including debugging information
(X_np, X_val_np, train_y, val_y, 
 num_col_x, num_1_valy, num_0_valy) = load_data.load_data_for_1_med_with_debug(del_med_thres=DeleteMedThreshold, 
                                                                               random_seed=1, 
                                                                               n=NumMedTrain,
                                                                               file_name=file_name)

# Ensure the correct data types for loaded variables
assert isinstance(X_np, np.ndarray)
assert isinstance(X_val_np, np.ndarray)
assert isinstance(train_y, pd.DataFrame)
assert isinstance(val_y, pd.DataFrame)
assert isinstance(num_col_x, int)
# Out:
# --------------------------------------------------------------------------------
# ReadData:
# Type of data: <class 'pandas.core.frame.DataFrame'>
# Shape of data = (797 rows, 215 cols).
# End of ReadData
# --------------------------------------------------------------------------------
# SplitXY:
# Shape of X = (796 rows, 111 cols).
# Shape of y = (796 rows, 102 cols).
# End of SplitXY
# --------------------------------------------------------------------------------
# In load_data_for_1_med_with_debug of load_data.py, random_seed= 1
# After SplitXY, total number of 0, 1 in y:
# Number of 0s: 72318
# Number of 1s: 8874
# save med num done
# Train_X.shape:  (637, 111)
# Train_y.shape:  (637, 102)
#
# Split Training Validation
# Number of 0s in train_y: 57978
# Number of 1s train_y: 6996
# Number of 0s in val_y: 14340
# Number of 1s val_y: 1878
# --------------------------------------------------------------------------------

# %% [markdown]
# # 3. Data Type Checking

# %%
# Uncomment the line below to display the DataFrame content and structure
# myutil.print_df(val_y, "---- y ----")

# Uncomment the line below to print the DataFrame directly
# print(val_y)

# Checking:

# Counting NA values in y
na_count = val_y.isna().sum().sum()

# Counting str values in y
str_count = val_y[val_y.map(type) == str].count().sum()

# Counting int values in y
int_count = val_y[val_y.map(type) == int].count().sum()

# Counting float values in y
float_count = val_y[val_y.map(type) == float].count().sum()

# Display the debugging information
print(f"Number of NA values in y: {na_count}")
print(f"Number of str values in y: {str_count}")
print(f"Number of int values in y: {int_count}")
print(f"Number of float values in y: {float_count}")
# Out:
# Number of NA values in y: 0
# Number of str values in y: 0
# Number of int values in y: 16218
# Number of float values in y: 0

# %% [markdown]
# # 4. Compute Class Weight

# %%
# Convert the 'train_y' DataFrame to a NumPy array
train_y_np = np.array(train_y)

# Determine the number of labels (columns) in the array
num_labels = train_y_np.shape[1]

# Initialize an empty dictionary to store class weights for each label
class_weight_dic = {}

# Iterate over each label column
for i in range(num_labels):
    # Count the occurrences of each class (0 and 1) in the current label column
    unique_values, counts = np.unique(train_y_np[:, i], return_counts=True)
    
    # Create a dictionary mapping class values to their frequencies
    value_frequency_dict = dict(zip(unique_values, counts))
    
    # Calculate the total number of occurrences for normalization
    total = value_frequency_dict.get(0, 0) + value_frequency_dict.get(1, 0)
    
    # Calculate class weights and store them in the dictionary
    class_weight_dic[i] = {0: (value_frequency_dict.get(1, 0) / total), 1: (value_frequency_dict.get(0, 0) / total)}

# Print the computed class weights for debuging
# print(class_weight_dic)
# Out:
# {0: {0: 0.1695447409733124, 1: 0.8304552590266876}, 1: {0: 0.42543171114599687, 1: 0.5745682888540031}, 2: {0: 0.03139717425431711, 1: 0.9686028257456829}, 3: {0: 0.058084772370486655, 1: 0.9419152276295133}, 4: {0: 0.28728414442700156, 1: 0.7127158555729984}, 5: {0: 0.01098901098901099, 1: 0.989010989010989}, 6: {0: 0.2857142857142857, 1: 0.7142857142857143}, 7: {0: 0.04709576138147567, 1: 0.9529042386185244}, 8: {0: 0.02040816326530612, 1: 0.9795918367346939}, 9: {0: 0.012558869701726845, 1: 0.9874411302982732}, 10: {0: 0.3218210361067504, 1: 0.6781789638932496}, 11: {0: 0.023547880690737835, 1: 0.9764521193092621}, 12: {0: 0.13186813186813187, 1: 0.8681318681318682}, 13: {0: 0.16326530612244897, 1: 0.8367346938775511}, 14: {0: 0.07535321821036106, 1: 0.9246467817896389}, 15: {0: 0.02040816326530612, 1: 0.9795918367346939}, 16: {0: 0.012558869701726845, 1: 0.9874411302982732}, 17: {0: 0.0141287284144427, 1: 0.9858712715855573}, 18: {0: 0.11145996860282574, 1: 0.8885400313971743}, 19: {0: 0.01098901098901099, 1: 0.989010989010989}, 20: {0: 0.04395604395604396, 1: 0.9560439560439561}, 21: {0: 0.026687598116169546, 1: 0.9733124018838305}, 22: {0: 0.21978021978021978, 1: 0.7802197802197802}, 23: {0: 0.39717425431711145, 1: 0.6028257456828885}, 24: {0: 0.06907378335949764, 1: 0.9309262166405023}, 25: {0: 0.13186813186813187, 1: 0.8681318681318682}, 26: {0: 0.17425431711145997, 1: 0.82574568288854}, 27: {0: 0.06750392464678179, 1: 0.9324960753532182}, 28: {0: 0.07849293563579278, 1: 0.9215070643642073}, 29: {0: 0.006279434850863423, 1: 0.9937205651491365}, 30: {0: 0.01098901098901099, 1: 0.989010989010989}, 31: {0: 0.0706436420722135, 1: 0.9293563579277865}, 32: {0: 0.009419152276295133, 1: 0.9905808477237049}, 33: {0: 0.32653061224489793, 1: 0.673469387755102}, 34: {0: 0.0989010989010989, 1: 0.9010989010989011}, 35: {0: 0.01098901098901099, 1: 0.989010989010989}, 36: {0: 0.007849293563579277, 1: 0.9921507064364207}, 37: {0: 0.35478806907378335, 1: 0.6452119309262166}, 38: {0: 0.007849293563579277, 1: 0.9921507064364207}, 39: {0: 0.03453689167974882, 1: 0.9654631083202512}, 40: {0: 0.08320251177394035, 1: 0.9167974882260597}, 41: {0: 0.004709576138147566, 1: 0.9952904238618524}, 42: {0: 0.01726844583987441, 1: 0.9827315541601256}, 43: {0: 0.009419152276295133, 1: 0.9905808477237049}, 44: {0: 0.2150706436420722, 1: 0.7849293563579278}, 45: {0: 0.4207221350078493, 1: 0.5792778649921507}, 46: {0: 0.09576138147566719, 1: 0.9042386185243328}, 47: {0: 0.14756671899529042, 1: 0.8524332810047096}, 48: {0: 0.13186813186813187, 1: 0.8681318681318682}, 49: {0: 0.14756671899529042, 1: 0.8524332810047096}, 50: {0: 0.009419152276295133, 1: 0.9905808477237049}, 51: {0: 0.018838304552590265, 1: 0.9811616954474097}, 52: {0: 0.02040816326530612, 1: 0.9795918367346939}, 53: {0: 0.130298273155416, 1: 0.869701726844584}, 54: {0: 0.04866562009419152, 1: 0.9513343799058085}, 55: {0: 0.018838304552590265, 1: 0.9811616954474097}, 56: {0: 0.012558869701726845, 1: 0.9874411302982732}, 57: {0: 0.1554160125588697, 1: 0.8445839874411303}, 58: {0: 0.271585557299843, 1: 0.728414442700157}, 59: {0: 0.0141287284144427, 1: 0.9858712715855573}, 60: {0: 0.012558869701726845, 1: 0.9874411302982732}, 61: {0: 0.14285714285714285, 1: 0.8571428571428571}, 62: {0: 0.009419152276295133, 1: 0.9905808477237049}, 63: {0: 0.058084772370486655, 1: 0.9419152276295133}, 64: {0: 0.03767660910518053, 1: 0.9623233908948194}, 65: {0: 0.23861852433281006, 1: 0.7613814756671899}, 66: {0: 0.03610675039246468, 1: 0.9638932496075353}, 67: {0: 0.04709576138147567, 1: 0.9529042386185244}, 68: {0: 0.08006279434850863, 1: 0.9199372056514914}, 69: {0: 0.01726844583987441, 1: 0.9827315541601256}, 70: {0: 0.03139717425431711, 1: 0.9686028257456829}, 71: {0: 0.10675039246467818, 1: 0.8932496075353218}, 72: {0: 0.015698587127158554, 1: 0.9843014128728415}, 73: {0: 0.06436420722135008, 1: 0.9356357927786499}, 74: {0: 0.17111459968602827, 1: 0.8288854003139717}, 75: {0: 0.03767660910518053, 1: 0.9623 ...

# %% [markdown]
# # 5. Build Model
#
# Adjust the dense layers, optimizer, activation function, loss function, and metrics for the model here if required.

# %%
# Define a Sequential model
model = Sequential([
    Dense(units=16, input_shape=(num_col_x,), activation='sigmoid'), 
    Dense(units=2, activation='sigmoid')
])

# Display a summary of the model architecture
model.summary()

# Compile the model with specified optimizer, loss function, and metrics
model.compile(optimizer=Adam(learning_rate=LearningRate),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 16)                1792
#
#  dense_17 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 1,826
# Trainable params: 1,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 6. Train Model
# Train one model for each medicine.
#
# Each model has same configuration as set in section **[5. Build Model]**

# %%
# Initialize dictionaries to store results and training history
result_df_dict = {}        # Dictionary of DataFrames of each medicine in training set 
accuracy_dict = {}         # Dictionary of accuracy for each medicine
prediction_train_dict = {}  # Dictionary of raw predictions for the training set
prediction_val_dict = {}    # Dictionary of raw predictions for the validation set

# Iterate over each medicine
for i in range(train_y.shape[1]):
    chosen_col = train_y.iloc[:, i].copy()
    
    # Ensure that the chosen column is a pandas Series
    assert(isinstance(chosen_col, pd.Series))
    assert(len(chosen_col) == len(train_y))
    
    print(f"Processing medicine {i + 1} of {train_y.shape[1]}: {chosen_col.name}")

    # Convert the chosen column to NumPy array
    chosen_y_np = chosen_col.values.astype('float64')

    # Copy the corresponding validation set column
    y_val_chosen_col = val_y.iloc[:, i].copy()
    
    # Ensure that the validation set column is a pandas Series
    assert(isinstance(y_val_chosen_col, pd.Series))
    assert(len(y_val_chosen_col) == len(val_y))

    # Early stopping callback
    early_stopping = EarlyStopping(monitor='loss', patience=30, restore_best_weights=True)

    # Fit the model for the current medicine
    Model = model.fit(
        x=X_np,
        y=chosen_y_np,
        class_weight=class_weight_dic[i] if UseClassWeight else None,
        epochs=2000,
        shuffle=True,
        verbose=0,
        callbacks=[early_stopping]
    )
    
    # Print when training stopped
    print(f"Training stopped at epoch {Model.epoch[-1]}")
    
    # Predict against the training set for diagnosing overfitting or underfitting
    predictions_train_set = model.predict(X_np)
    
    # Save raw result numpy array of training set to the dictionary
    prediction_train_dict[chosen_col.name] = predictions_train_set
    
    # Make predictions for the validation set
    predictions_val_set = model.predict(X_val_np)
    
    # Save raw result numpy array of validation set to the dictionary
    prediction_val_dict[chosen_col.name] = predictions_val_set
    
    # Uncomment to plot model history
    
    # Plotting loss vs. epoch
    # plt.plot(Model.history['loss'], label='Training Loss')
    # plt.title('Loss vs. Epoch')
    # plt.xlabel('Epoch')
    # plt.ylabel('Loss')
    # plt.legend()
    # plt.show()

print("Training done.")
# Out:
# Processing medicine 1 of 102: 麻黃
# Training stopped at epoch 664
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 2 of 102: 桂枝
# Training stopped at epoch 544
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 3 of 102: 荊芥
# Training stopped at epoch 213
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 4 of 102: 防風
# Training stopped at epoch 144
# 20/20 [==============================] - 0s 852us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 5 of 102: 細辛
# Training stopped at epoch 525
# 20/20 [==============================] - 0s 268us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 6 of 102: 白芷
# Training stopped at epoch 216
# 20/20 [==============================] - 0s 823us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 7 of 102: 生薑
# Training stopped at epoch 470
# 20/20 [==============================] - 0s 823us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 8 of 102: 辛夷
# Training stopped at epoch 264
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 9 of 102: 葛根
# Training stopped at epoch 255
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 10 of 102: 升麻
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 773us/step
# Processing medicine 11 of 102: 柴胡
# Training stopped at epoch 766
# 20/20 [==============================] - 0s 901us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 12 of 102: 蟬蛻
# Training stopped at epoch 530
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 13 of 102: 石膏
# Training stopped at epoch 717
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 14 of 102: 知母
# Training stopped at epoch 836
# 20/20 [==============================] - 0s 823us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 15 of 102: 梔子
# Training stopped at epoch 1141
# 20/20 [==============================] - 0s 824us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 16 of 102: 天花粉
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 17 of 102: 夏枯草
# Training stopped at epoch 487
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 18 of 102: 決明子
# Training stopped at epoch 408
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 19 of 102: 生地
# Training stopped at epoch 827
# 20/20 [==============================] - 0s 823us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 20 of 102: 牡丹皮
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 21 of 102: 連翹
# Training stopped at epoch 1286
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 22 of 102: 射干
# Training stopped at epoch 862
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 23 of 102: 黃連
# Training stopped at epoch 1389
# 20/20 [==============================] - 0s 851us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 24 of 102: 黃芩
# Training stopped at epoch 1859
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 25 of 102: 黃柏
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 823us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 26 of 102: 龍膽草
# Training stopped at epoch 1724
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 3ms/step
# Processing medicine 27 of 102: 大黃
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 28 of 102: 芒硝
# Training stopped at epoch 834
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 29 of 102: 防己
# Training stopped at epoch 1488
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 30 of 102: 秦艽
# Training stopped at epoch 1097
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 31 of 102: 絡石藤
# Training stopped at epoch 1270
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 32 of 102: 蒼朮
# Training stopped at epoch 162
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 33 of 102: 草果
# Training stopped at epoch 1043
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 34 of 102: 茯苓
# Training stopped at epoch 1872
# 20/20 [==============================] - 0s 685us/step
# 5/5 [==============================] - 0s 2ms/step
# Processing medicine 35 of 102: 豬苓
# Training stopped at epoch 599
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 3ms/step
# Processing medicine 36 of 102: 薏苡仁
# Training stopped at epoch 677
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 37 of 102: 海金砂
# Training stopped at epoch 1020
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 38 of 102: 澤瀉
# Training stopped at epoch 1067
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 39 of 102: 車前子
# Training stopped at epoch 292
# 20/20 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 40 of 102: 滑石
# Training stopped at epoch 81
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 41 of 102: 木通
# Training stopped at epoch 1596
# 20/20 [==============================] - 0s 851us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 42 of 102: 通草
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 43 of 102: 赤小豆
# Training stopped at epoch 273
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 44 of 102: 燈心草
# Training stopped at epoch 141
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 45 of 102: 乾薑
# Training stopped at epoch 577
# 20/20 [==============================] - 0s 399us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 46 of 102: 附子
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 47 of 102: 吳茱萸
# Training stopped at epoch 1641
# 20/20 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 48 of 102: 枳實
# Training stopped at epoch 1458
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 49 of 102: 烏藥
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 50 of 102: 厚朴
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 823us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 51 of 102: 大腹皮
# Training stopped at epoch 823
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 52 of 102: 青皮
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 475us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 53 of 102: 薤白
# Training stopped at epoch 1497
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 54 of 102: 麥芽
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 1ms/step
# Processing medicine 55 of 102: 側柏葉
# Training stopped at epoch 1757
# 20/20 [==============================] - 0s 818us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 56 of 102: 槐花
# Training stopped at epoch 1436
# 20/20 [==============================] - 0s 689us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 57 of 102: 三七
# Training stopped at epoch 1535
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 58 of 102: 茜草
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 820us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 59 of 102: 川芎
# Training stopped at epoch 1064
# 20/20 [==============================] - 0s 636us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 60 of 102: 乳香
# Training stopped at epoch 1430
# 20/20 [==============================] - 0s 851us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 61 of 102: 延胡索
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 815us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 62 of 102: 鬱金
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 63 of 102: 紅花
# Training stopped at epoch 1103
# 20/20 [==============================] - 0s 824us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 64 of 102: 桃仁
# Training stopped at epoch 819
# 20/20 [==============================] - 0s 829us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 65 of 102: 牛膝
# Training stopped at epoch 1747
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 66 of 102: 半夏
# Training stopped at epoch 669
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 67 of 102: 白附子
# Training stopped at epoch 1882
# 20/20 [==============================] - 0s 610us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 68 of 102: 桔梗
# Training stopped at epoch 1356
# 20/20 [==============================] - 0s 823us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 69 of 102: 旋覆花
# Training stopped at epoch 607
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 70 of 102: 瓜蔞
# Training stopped at epoch 1594
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 71 of 102: 海藻
# Training stopped at epoch 1859
# 20/20 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 72 of 102: 杏仁
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 347us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 73 of 102: 紫菀
# Training stopped at epoch 1249
# 20/20 [==============================] - 0s 932us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 74 of 102: 龍骨
# Training stopped at epoch 1776
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 75 of 102: 牡蠣
# Training stopped at epoch 391
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 76 of 102: 酸棗仁
# Training stopped at epoch 1836
# 20/20 [==============================] - 0s 823us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 77 of 102: 遠志
# Training stopped at epoch 271
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 78 of 102: 小麥
# Training stopped at epoch 1342
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 79 of 102: 代赭石
# Training stopped at epoch 1891
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 80 of 102: 黃耆
# Training stopped at epoch 1381
# 20/20 [==============================] - 0s 828us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 81 of 102: 白朮
# Training stopped at epoch 234
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 82 of 102: 大棗
# Training stopped at epoch 279
# 20/20 [==============================] - 0s 847us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 83 of 102: 甘草
# Training stopped at epoch 648
# 20/20 [==============================] - 0s 711us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 84 of 102: 巴戟天
# Training stopped at epoch 1671
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 85 of 102: 補骨脂
# Training stopped at epoch 1518
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 86 of 102: 益智仁
# Training stopped at epoch 948
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 87 of 102: 陽起石
# Training stopped at epoch 353
# 20/20 [==============================] - 0s 136us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 88 of 102: 續斷
# Training stopped at epoch 679
# 20/20 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 89 of 102: 杜仲
# Training stopped at epoch 504
# 20/20 [==============================] - 0s 848us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 90 of 102: 何首烏
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 823us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 91 of 102: 當歸
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 92 of 102: 白芍
# Training stopped at epoch 507
# 20/20 [==============================] - 0s 821us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 93 of 102: 阿膠
# Training stopped at epoch 991
# 20/20 [==============================] - 0s 823us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 94 of 102: 西洋參
# Training stopped at epoch 1307
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 95 of 102: 龜板
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 827us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 96 of 102: 鱉甲
# Training stopped at epoch 1013
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 97 of 102: 山茱萸
# Training stopped at epoch 1493
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 98 of 102: 覆盆子
# Training stopped at epoch 485
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 99 of 102: 五味子
# Training stopped at epoch 1999
# 20/20 [==============================] - 0s 826us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 100 of 102: 烏梅
# Training stopped at epoch 916
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 0s/step
# Processing medicine 101 of 102: 五倍子
# Training stopped at epoch 916
# 20/20 [==============================] - 0s 822us/step
# 5/5 [==============================] - 0s 4ms/step
# Processing medicine 102 of 102: 炙甘草
# Training stopped at epoch 706
# 20/20 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 1ms/step
# Training done.

# %% [markdown]
# # 7. Handle result
#
#
# 7.1 Calculate the f1 score, precision, recall, TP, FP, TN, FN of the training dataset and store the values in TrainMedicineDictioanry

# %%
# Calculate True Positives (TP), False Positives (FP), True Negatives (TN), and False Negatives (FN) for the training set
total_tp_train = 0
total_fp_train = 0
total_tn_train = 0
total_fn_train = 0

# Create a dictioanry to store all values of a medicine
TrainMedicineDictioanry = {}

# Iterate through each medicine's raw prediction array
for key, arr in prediction_train_dict.items():
    
    # Create a DataFrame from the raw prediction array
    df_tmp = pd.DataFrame(arr, columns=["predicted as 0", "predicted as 1"])

    # Determine the predicted value based on probabilities
    df_tmp["predicted value"] = np.where(df_tmp["predicted as 0"] > df_tmp["predicted as 1"], 0, 1)
    
    # Get the column number of the current medicine in the training labels
    col_num = train_y.columns.get_loc(key)
    
    # Add ground truth values to the DataFrame
    df_tmp["ground truth"] = train_y.iloc[:, col_num].copy().values
    
    
    TP = ((df_tmp['ground truth'] == 1) & (df_tmp['predicted value'] == 1)).sum()
    FP = ((df_tmp['ground truth'] == 0) & (df_tmp['predicted value'] == 1)).sum()
    FN = ((df_tmp['ground truth'] == 1) & (df_tmp['predicted value'] == 0)).sum()
    TN = ((df_tmp['ground truth'] == 0) & (df_tmp['predicted value'] == 0)).sum()
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    
    # Calculate TP, FP, FN, TN for the current medicine
    total_tp_train += TP
    total_fp_train += FP
    total_fn_train += FN
    total_tn_train += TN
    
    TrainMedicineDictioanry[key] = {
        "TP" : TP,
        "FP" : FP,
        "FN" : FN,
        "TN" : TN,
        "precision" : precision,
        "recall" : recall,
        "f1-score" : f1score
    }

precision = total_tp_train / (total_tp_train + total_fp_train) if (total_tp_train + total_fp_train) > 0 else 0
recall = total_tp_train / (total_tp_train + total_fn_train) if (total_tp_train + total_fn_train) > 0 else 0

TrainMedicineDictioanry["overall"] = {
        "TP" : total_tp_train,
        "FP" : total_fp_train,
        "FN" : total_fn_train,
        "TN" : total_tn_train,
        "precision" : precision,
        "recall" : recall,
        "f1-score" : 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
}

print("TrainMedicineDictioanry:")
for key in TrainMedicineDictioanry:
    print(key, TrainMedicineDictioanry[key])
# print("overall", TrainMedicineDictioanry["overall"])
# Out:
# TrainMedicineDictioanry:
# 麻黃 {'TP': 102, 'FP': 11, 'FN': 6, 'TN': 518, 'precision': 0.9026548672566371, 'recall': 0.9444444444444444, 'f1-score': 0.9230769230769231}
# 桂枝 {'TP': 262, 'FP': 6, 'FN': 9, 'TN': 360, 'precision': 0.9776119402985075, 'recall': 0.966789667896679, 'f1-score': 0.9721706864564007}
# 荊芥 {'TP': 20, 'FP': 35, 'FN': 0, 'TN': 582, 'precision': 0.36363636363636365, 'recall': 1.0, 'f1-score': 0.5333333333333333}
# 防風 {'TP': 37, 'FP': 35, 'FN': 0, 'TN': 565, 'precision': 0.5138888888888888, 'recall': 1.0, 'f1-score': 0.6788990825688073}
# 細辛 {'TP': 178, 'FP': 6, 'FN': 5, 'TN': 448, 'precision': 0.967391304347826, 'recall': 0.9726775956284153, 'f1-score': 0.9700272479564033}
# 白芷 {'TP': 7, 'FP': 31, 'FN': 0, 'TN': 599, 'precision': 0.18421052631578946, 'recall': 1.0, 'f1-score': 0.3111111111111111}
# 生薑 {'TP': 181, 'FP': 31, 'FN': 1, 'TN': 424, 'precision': 0.8537735849056604, 'recall': 0.9945054945054945, 'f1-score': 0.9187817258883249}
# 辛夷 {'TP': 30, 'FP': 34, 'FN': 0, 'TN': 573, 'precision': 0.46875, 'recall': 1.0, 'f1-score': 0.6382978723404256}
# 葛根 {'TP': 13, 'FP': 36, 'FN': 0, 'TN': 588, 'precision': 0.2653061224489796, 'recall': 1.0, 'f1-score': 0.41935483870967744}
# 升麻 {'TP': 8, 'FP': 0, 'FN': 0, 'TN': 629, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}
# 柴胡 {'TP': 202, 'FP': 6, 'FN': 3, 'TN': 426, 'precision': 0.9711538461538461, 'recall': 0.9853658536585366, 'f1-score': 0.9782082324455206}
# 蟬蛻 {'TP': 15, 'FP': 31, 'FN': 0, 'TN': 591, 'precision': 0.32608695652173914, 'recall': 1.0, 'f1-score': 0.4918032786885246}
# 石膏 {'TP': 81, 'FP': 11, 'FN': 3, 'TN': 542, 'precision': 0.8804347826086957, 'recall': 0.9642857142857143, 'f1-score': 0.9204545454545455}
# 知母 {'TP': 102, 'FP': 11, 'FN': 2, 'TN': 522, 'precision': 0.9026548672566371, 'recall': 0.9807692307692307, 'f1-score': 0.9400921658986174}
# 梔子 {'TP': 48, 'FP': 5, 'FN': 0, 'TN': 584, 'precision': 0.9056603773584906, 'recall': 1.0, 'f1-score': 0.9504950495049505}
# 天花粉 {'TP': 13, 'FP': 0, 'FN': 0, 'TN': 624, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}
# 夏枯草 {'TP': 8, 'FP': 33, 'FN': 0, 'TN': 596, 'precision': 0.1951219512195122, 'recall': 1.0, 'f1-score': 0.326530612244898}
# 決明子 {'TP': 9, 'FP': 30, 'FN': 0, 'TN': 598, 'precision': 0.23076923076923078, 'recall': 1.0, 'f1-score': 0.375}
# 生地 {'TP': 70, 'FP': 7, 'FN': 1, 'TN': 559, 'precision': 0.9090909090909091, 'recall': 0.9859154929577465, 'f1-score': 0.9459459459459459}
# 牡丹皮 {'TP': 7, 'FP': 0, 'FN': 0, 'TN': 630, 'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0}
# 連翹 {'TP': 27, 'FP': 7, 'FN': 1, 'TN': 602, 'precision': 0.7941176470588235, 'recall': 0.9642857142857143, 'f1-score': 0.8709677419354839}
# 射干 {'TP': 17, 'FP': 4, 'FN': 0, 'TN': 616, 'precision': 0.8095238095238095, 'recall': 1.0, 'f1-score': 0.8947368421052632}
# 黃連 {'TP': 131, 'FP': 9, 'FN': 9, 'TN': 488, 'precision': 0.9357142857142857, 'recall': 0.9357142857142857, 'f1-score': 0.9357142857142857}
# 黃芩 {'TP': 244, 'FP': 23, 'FN': 9, 'TN': 361, 'precision': 0.9138576779026217, 'recall': 0.9644268774703557, 'f1-score': 0.9384615384615385}
# 黃柏 {'TP': 42, 'FP': 7, 'FN': 2, 'TN': 586, 'precision': 0.8571428571428571, 'recall': 0.9545454545454546, 'f1-score': 0.9032258064516128}
# 龍膽草 {'TP': 82, 'FP': 97, 'FN': 2, 'TN': 456, 'precision': 0.4581005586592179, 'recall': 0.9761904761904762, 'f1-score': 0.623574144486692}
# 大黃 {'TP': 106, 'FP': 80, 'FN': 5, 'TN': 446, 'precision': 0.5698924731182796, 'recall': 0.954954954954955, 'f1-score': 0.7138047138047139}
# 芒硝 {'TP': 42, 'FP': 45, 'FN': 1, 'TN': 549, 'precision': 0.4827586206896552, 'recall': 0.9767441860465116, 'f1-score': 0.6461538461538461}
# 防己 {'TP': 47, 'FP': 26, 'FN': 3, 'TN': 561, 'precision': 0.6438356164383562, 'recall': 0.94, 'f1-score': 0.7642276422764229}
# 秦艽 {'TP': 4, 'FP': 70, 'FN': 0, 'TN': 563, 'precision': 0.05405405405405406, 'recall': 1.0, 'f1-score': 0.10256410256410257}
# 絡石藤 {'TP': 7, 'FP': 15, 'FN': 0, 'TN': 615, 'precision': 0.3181818181818182, 'recall': 1.0, 'f1-score': 0.4827586206896552}
# 蒼朮 {'TP': 6, 'FP': 27, 'FN': 39, 'TN': 565, 'precision': 0.18181818181818182, 'recall': 0.13333333333333333, 'f1-score': 0.15384615384615383}
# 草果 {'TP': 6, 'FP': 28, 'FN': 0, 'TN': 603, 'precision': 0.17647058823529413, 'recall': 1.0, 'f1-score': 0.3}
# 茯苓 {'TP': 202, 'FP': 203, 'FN': 6, 'TN': 226, 'precision': 0.49876543209876545, 'recall': 0.9711538461538461, 'f1-score': 0.6590538336052202}
# 豬苓 {'TP': 59, 'FP': 168, 'FN': 4, 'TN': 406, 'precision': 0.2599118942731278, 'recall': 0.9365079365079365, 'f1-score': 0.40689655172413797}
# 薏苡仁 {'TP': 5, 'FP': 56, 'FN': 2, 'TN': 574, 'precision': 0.08196721311475409, 'recall': 0.7142857142857143, 'f1-score': 0.14705882352941174}
# 海金砂 {'TP': 5, 'FP': 35, 'FN': 0, 'TN': 597, 'precision': 0.125, 'recall': 1.0, 'f1-score': 0.2222222222222222}
# 澤瀉 {'TP': 118, 'FP': 11, 'FN': 108, 'TN': 400, 'precision': 0.9147286821705426, 'recall': 0.5221238938053098, 'f1-score': 0.6647887323943662}
# 車前子 {'TP': 4, 'FP': 15, 'FN': 1, 'TN': 617, 'precision': 0.21052631578947367, 'recall': 0.8, 'f1-score': 0.3333333333333333}
# 滑石 {'TP': 9, 'FP': 9, 'FN': 13, 'TN': 606, 'precision': 0.5, 'recall': 0.4090909090909091, 'f1-score': 0.45}
# 木通 {'TP': 53, 'FP': 167, 'FN': 0, 'TN': 417, 'precision': 0.2409090909090909, 'recall': 1.0, 'f1-score': 0.38827838827838823}
# 通草 {'TP': 3, 'FP': 5, 'FN': 0, 'TN': 629, 'precision': 0.375, 'recall': 1.0, 'f1-score': 0.5454545454545454}
# 赤小豆 {'TP': 1, 'FP': 3, 'FN': 10, 'TN': 623, 'precision': 0.25, 'recall': 0.09090909090909091, 'f1-score': 0.13333333333333333}
# 燈心草 {'TP': 2, 'FP': 3, 'FN': 4, 'TN': 628, 'precision': 0.4, 'recall': 0.3333333333333333, 'f1-score': 0.3636363636363636}
# 乾薑 {'TP': 31, 'FP': 1, 'FN': 106, 'TN': 499, 'precision': 0.96875, 'recall': 0.22627737226277372, 'f1-score': 0.3668639053254438}
# 附子 {'TP': 258, 'FP': 111, 'FN': 10, 'TN': 258, 'precision': 0.6991869918699187, 'recall': 0.9626865671641791, 'f1-score': 0.8100470957613815}
# 吳茱萸 {'TP': 58, 'FP': 24, 'FN': 3, 'TN': 552, 'precision': 0.7073170731707317, 'recall': 0.9508196721311475, 'f1-score': 0.8111888111888113}
# 枳實 {'TP': 82, 'FP': 25, 'FN': 12, 'TN': 518, 'precision': 0.7663551401869159, 'recall': 0.8723404255319149, 'f1-score': 0.8159203980099503}
# 烏藥 {'TP': 81, 'FP': 38, 'FN': 3, 'TN': 515, 'precision': 0.680672268907563, 'recall': 0.9642857142857143, 'f1-score': 0.7980295566502464}
# 厚朴 {'TP': 81, 'FP': 47, 'FN': 13, 'TN': 496, 'precision': 0.6328125, 'recall': 0.8617021276595744, 'f1-score': 0.7297297297297297}
# 大腹皮 {'TP': 6, 'FP': 51, 'FN': 0, 'TN': 580, 'precision': 0.10526315789473684, 'recall': 1.0, 'f1-score': 0.1904761904761905}
# 青皮 {'TP': 12, 'FP': 23, 'FN': 0, 'TN': 602, 'precision': 0.34285714285714286, 'recall': 1.0, 'f1-score': 0.5106382978723404}
# 薤白 {'TP': 13, 'FP': 34, 'FN': 0, 'TN': 590, 'precision': 0.2765957446808511, 'recall': 1.0, 'f1-score': 0.43333333333333335}
# 麥芽 {'TP': 64, 'FP': 56, 'FN': 19, 'TN': 498, 'precision': 0.5333333333333333, 'recall': 0.7710843373493976, 'f1-score': 0.6305418719211823}
# 側柏葉 {'TP': 30, 'FP': 20, 'FN': 1, 'TN': 586, 'precision': 0.6, 'recall': 0.967741935483871, 'f1-score': 0.7407407407407407}
# 槐花 {'TP': 12, 'FP': 107, 'FN': 0, 'TN': 518, 'precision': 0.10084033613445378, 'recall': 1.0, 'f1-score': 0.183206106870229}
# 三七 {'TP': 8, 'FP': 21, 'FN': 0, 'TN': 608, 'precision': 0.27586206896551724, 'recall': 1.0, 'f1-score': 0.4324324324324324}
# 茜草 {'TP': 96, 'FP': 57, 'FN': 3, 'TN': 481, 'precision': 0.6274509803921569, 'recall': 0.9696969696969697, 'f1-score': 0.761904761904762}
# 川芎 {'TP': 133, 'FP': 86, 'FN': 40, 'TN': 378, 'precision': 0.6073059360730594, 'recall': 0.7687861271676301, 'f1-score': 0.6785714285714286}
# 乳香 {'TP': 9, 'FP': 14, 'FN': 0, 'TN': 614, 'precision': 0.391304347826087, 'recall': 1.0, 'f1-score': 0.5625}
# 延胡索 {'TP': 8, 'FP': 7, 'FN': 0, 'TN': 622, 'precision': 0.5333333333333333, 'recall': 1.0, 'f1-score': 0.6956521739130436}
# 鬱金 {'TP': 88, 'FP': 91, 'FN': 3, 'TN': 455, 'precision': 0.49162011173184356, 'recall': 0.967032967032967, 'f1-score': 0.6518518518518518}
# 紅花 {'TP': 6, 'FP': 4, 'FN': 0, 'TN': 627, 'precision': 0.6, 'recall': 1.0, 'f1-score': 0.7499999999999999}
# 桃仁 {'TP': 36, 'FP': 69, 'FN': 1, 'TN': 531, 'precision': 0.34285714285714286, 'recall': 0.972972972972973, 'f1-score': 0.5070422535211268}
# 牛膝 {'TP': 21, 'FP': 37, 'FN': 3, 'TN': 576, 'precision': 0.3620689655172414, 'recall': 0.875, 'f1-score': 0.5121951219512195}
# 半夏 {'TP': 126, 'FP': 268, 'FN': 26, 'TN': 217, 'precision': 0.3197969543147208, 'recall': 0.8289473684210527, 'f1-score': 0.46153846153846156}
# 白附子 {'TP': 22, 'FP': 19, 'FN': 1, 'TN': 595, 'precision': 0.5365853658536586, 'recall': 0.9565217391304348, 'f1-score': 0.6875000000000001}
# 桔梗 {'TP': 24, 'FP': 29, 'FN': 6, 'TN': 578, 'precision': 0.4528301886792453, 'recall': 0.8, 'f1-score': 0.5783132530120482}
# 旋覆花 {'TP': 27, 'FP': 40, 'FN': 24, 'TN': 546, 'precision': 0.40298507462686567, 'recall': 0.5294117647058824, 'f1-score': 0.45762711864406785}
# 瓜蔞 {'TP': 11, 'FP': 19, 'FN': 0, 'TN': 607, 'precision': 0.36666666666666664, 'recall': 1.0, 'f1-score': 0.5365853658536585}
# 海藻 {'TP': 19, 'FP': 20, 'FN': 1, 'TN': 597, 'precision': 0.48717948717948717, 'recall': 0.95, 'f1-score': 0.6440677966101694}
# 杏仁 {'TP': 58, 'FP': 94, 'FN': 10, 'TN': 475, 'precision': 0.3815789473684211, 'recall': 0.8529411764705882, 'f1-score': 0.5272727272727272}
# 紫菀 {'TP': 10, 'FP': 40, 'FN': 0, 'TN': 587, 'precision': 0.2, 'recall': 1.0, 'f1-score': 0.33333333333333337}
# 龍骨 {'TP': 40, 'FP': 139, 'FN': 1, 'TN': 457, 'precision': 0.22346368715083798, 'recall': 0.975609756097561, 'f1-score': 0.36363636363636365}
# 牡蠣 {'TP': 82, 'FP': 115, 'FN': 27, 'TN': 413, 'precision': 0.41624365482233505, 'recall': 0.7522935779816514, 'f1-score': 0.5359477124183007}
# 酸棗仁 {'TP': 24, 'FP': 119, 'FN': 0, 'TN': 494, 'precision': 0.16783216783216784, 'recall': 1.0, 'f1-score': 0.2874251497005988}
# 遠志 {'TP': 13, 'FP': 113, 'FN': 19, 'TN': 492, 'precision': 0.10317460317460317, 'recall': 0.40625, 'f1-score': 0.16455696202531644}
# 小麥 {'TP': 11, 'FP': 143, 'FN': 0, 'TN': 483, 'precision': 0.07142857142857142, 'recall': 1.0, 'f1-score': 0.13333333333333333}
# 代赭石 {'TP': 57, 'FP': 49, 'FN': 5, 'TN': 526, 'precision': 0.5377358490566038, 'recall': 0.9193548387096774, 'f1-score': 0.6785714285714285}
# 黃耆 {'TP': 32, 'FP': 125, 'FN': 6, 'TN': 474, 'precision': 0.20382165605095542, 'recall': 0.8421052631578947, 'f1-score': 0.32820512820512826}
# 白朮 {'TP': 82, 'FP': 86, 'FN': 96, 'TN': 373, 'precision': 0.4880952380952381, 'recall': 0.4606741573033708, 'f1-score': 0.47398843930635837}
# 大棗 {'TP': 45, 'FP': 68, 'FN': 118, 'TN': 406, 'precision': 0.39823008849557523, 'recall': 0.27607361963190186, 'f1-score': 0.32608695652173914}
# 甘草 {'TP': 130, 'FP': 32, 'FN': 231, 'TN': 244, 'precision': 0.8024691358024691, 'recall': 0.3601108033240997, 'f1-score': 0.49713193116634796}
# 巴戟天 {'TP': 23, 'FP': 95, 'FN': 0, 'TN': 519, 'precision': 0.19491525423728814, 'recall': 1.0, 'f1-score': 0.3262411347517731}
# 補骨脂 {'TP': 116, 'FP': 111, 'FN': 40, 'TN': 370, 'precision': 0.5110132158590308, 'recall': 0.7435897435897436, 'f1-score': 0.6057441253263708}
# 益智仁 {'TP': 5, 'FP': 11, 'FN': 1, 'TN': 620, 'precision': 0.3125, 'recall': 0.8333333333333334, 'f1-score': 0.45454545454545453}
# 陽起石 {'TP': 21, 'FP': 126, 'FN': 19, 'TN': 471, 'precision': 0.14285714285714285, 'recall': 0.525, 'f1-score': 0.2245989304812834}
# 續斷 {'TP': 11, 'FP': 331, 'FN': 0, 'TN': 295, 'precision': 0.03216374269005848, 'recall': 1.0, 'f1-score': 0.06232294617563739}
# 杜仲 {'TP': 9, 'FP': 103, 'FN': 6, 'TN': 519, 'precision': 0.08035714285714286, 'recall': 0.6, 'f1-score': 0.14173228346456693}
# 何首烏 {'TP': 15, 'FP': 14, 'FN': 2, 'TN': 606, 'precision': 0.5172413793103449, 'recall': 0.8823529411764706, 'f1-score': 0.6521739130434783}
# 當歸 {'TP': 176, 'FP': 131, 'FN': 35, 'TN': 295, 'precision': 0.5732899022801303, 'recall': 0.8341232227488151, 'f1-score': 0.6795366795366796}
# 白芍 {'TP': 233, 'FP': 107, 'FN': 93, 'TN': 204, 'precision': 0.6852941176470588, 'recall': 0.7147239263803681, 'f1-score': 0.6996996996996997}
# 阿膠 {'TP': 71, 'FP': 166, 'FN': 12, 'TN': 388, 'precision': 0.29957805907172996, 'recall': 0.8554216867469879, 'f1-score': 0.44375}
# 西洋參 {'TP': 5, 'FP': 109, 'FN': 0, 'TN': 523, 'precision': 0.043859649122807015, 'recall': 1.0, 'f1-score': 0.08403361344537816}
# 龜板 {'TP': 25, 'FP': 75, 'FN': 2, 'TN': 535, 'precision': 0.25, 'recall': 0.9259259259259259, 'f1-score': 0.39370078740157477}
# 鱉甲 {'TP': 33, 'FP': 217, 'FN': 3, 'TN': 384, 'precision': 0.132, 'recall': 0.9166666666666666, 'f1-score': 0.23076923076923078}
# 山茱萸 {'TP': 12, 'FP': 63, 'FN': 0, 'TN': 562, 'precision': 0.16, 'recall': 1.0, 'f1-score': 0.2758620689655173}
# 覆盆子 {'TP': 5, 'FP': 172, 'FN': 2, 'TN': 458, 'precision': 0.02824858757062147, 'recall': 0.7142857142857143, 'f1-score': 0.05434782608695652}
# 五味子 {'TP': 22, 'FP': 43, 'FN': 1, 'TN': 571, 'precision': 0.3384615384615385, 'recall': 0.9565217391304348, 'f1-score': 0.5000000000000001}
# 烏梅 {'TP': 9, 'FP': 102, 'FN': 0, 'TN': 526, 'precision': 0.08108108108108109, 'recall': 1.0, 'f1-score': 0.15}
# 五倍子 {'TP': 10, 'FP': 73, 'FN': 0, 'TN': 554, 'precision': 0.12048192771084337, 'recall': 1.0, 'f1-score': 0.21505376344086022}
# 炙甘草 {'TP': 294, 'FP': 138, 'FN': 87, 'TN': 118, 'precision': 0.6805555555555556, 'recall': 0.7716535433070866, 'f1-score': 0.7232472324723247}
# overall {'TP': 5656, 'FP': 6100, 'FN': 1340, 'TN': 51878, 'precision': 0.48111602585913577, 'recall': 0.808461978273299, 'f1-score': 0.6032423208191127}

# %% [markdown]
# 7.2 Calculate the f1 score, precision, recall, TP, FP, TN, FN of the validation dataset and store the values in ValMedicineDictioanry

# %%
# Calculate True Positives (TP), False Positives (FP), True Negatives (TN), and False Negatives (FN) for the training set
total_tp_train = 0
total_fp_train = 0
total_tn_train = 0
total_fn_train = 0

# Create a dictioanry to store all values of a medicine
ValMedicineDictioanry = {}

# Iterate through each medicine's raw prediction array
for key, arr in prediction_val_dict.items():
    
    # Create a DataFrame from the raw prediction array
    df_tmp = pd.DataFrame(arr, columns=["predicted as 0", "predicted as 1"])

    # Determine the predicted value based on probabilities
    df_tmp["predicted value"] = np.where(df_tmp["predicted as 0"] > df_tmp["predicted as 1"], 0, 1)
    
    # Get the column number of the current medicine in the training labels
    col_num = val_y.columns.get_loc(key)
    
    # Add ground truth values to the DataFrame
    df_tmp["ground truth"] = val_y.iloc[:, col_num].copy().values
    result_df_dict[key] = df_tmp
    
    TP = ((df_tmp['ground truth'] == 1) & (df_tmp['predicted value'] == 1)).sum()
    FP = ((df_tmp['ground truth'] == 0) & (df_tmp['predicted value'] == 1)).sum()
    FN = ((df_tmp['ground truth'] == 1) & (df_tmp['predicted value'] == 0)).sum()
    TN = ((df_tmp['ground truth'] == 0) & (df_tmp['predicted value'] == 0)).sum()
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    
    # Calculate TP, FP, FN, TN for the current medicine
    total_tp_train += TP
    total_fp_train += FP
    total_fn_train += FN
    total_tn_train += TN
    
    ValMedicineDictioanry[key] = {
        "TP" : TP,
        "FP" : FP,
        "FN" : FN,
        "TN" : TN,
        "precision" : precision,
        "recall" : recall,
        "f1-score" : f1score
    }

precision = total_tp_train / (total_tp_train + total_fp_train) if (total_tp_train + total_fp_train) > 0 else 0
recall = total_tp_train / (total_tp_train + total_fn_train) if (total_tp_train + total_fn_train) > 0 else 0

ValMedicineDictioanry["overall"] = {
        "TP" : total_tp_train,
        "FP" : total_fp_train,
        "FN" : total_fn_train,
        "TN" : total_tn_train,
        "precision" : precision,
        "recall" : recall,
        "f1-score" : 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
}

print("ValMedicineDictioanry:")
for key in ValMedicineDictioanry:
    print(key, ValMedicineDictioanry[key])
# print("overall", ValMedicineDictioanry["overall"])
# Out:
# ValMedicineDictioanry:
# 麻黃 {'TP': 5, 'FP': 15, 'FN': 19, 'TN': 120, 'precision': 0.25, 'recall': 0.20833333333333334, 'f1-score': 0.22727272727272727}
# 桂枝 {'TP': 28, 'FP': 31, 'FN': 38, 'TN': 62, 'precision': 0.4745762711864407, 'recall': 0.42424242424242425, 'f1-score': 0.448}
# 荊芥 {'TP': 0, 'FP': 8, 'FN': 0, 'TN': 151, 'precision': 0.0, 'recall': 0, 'f1-score': 0}
# 防風 {'TP': 1, 'FP': 11, 'FN': 4, 'TN': 143, 'precision': 0.08333333333333333, 'recall': 0.2, 'f1-score': 0.11764705882352941}
# 細辛 {'TP': 30, 'FP': 23, 'FN': 36, 'TN': 70, 'precision': 0.5660377358490566, 'recall': 0.45454545454545453, 'f1-score': 0.5042016806722689}
# 白芷 {'TP': 0, 'FP': 9, 'FN': 2, 'TN': 148, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 生薑 {'TP': 13, 'FP': 39, 'FN': 20, 'TN': 87, 'precision': 0.25, 'recall': 0.3939393939393939, 'f1-score': 0.30588235294117644}
# 辛夷 {'TP': 1, 'FP': 16, 'FN': 6, 'TN': 136, 'precision': 0.058823529411764705, 'recall': 0.14285714285714285, 'f1-score': 0.08333333333333333}
# 葛根 {'TP': 1, 'FP': 10, 'FN': 3, 'TN': 145, 'precision': 0.09090909090909091, 'recall': 0.25, 'f1-score': 0.13333333333333333}
# 升麻 {'TP': 0, 'FP': 2, 'FN': 6, 'TN': 151, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 柴胡 {'TP': 28, 'FP': 31, 'FN': 28, 'TN': 72, 'precision': 0.4745762711864407, 'recall': 0.5, 'f1-score': 0.4869565217391304}
# 蟬蛻 {'TP': 1, 'FP': 11, 'FN': 0, 'TN': 147, 'precision': 0.08333333333333333, 'recall': 1.0, 'f1-score': 0.15384615384615385}
# 石膏 {'TP': 4, 'FP': 11, 'FN': 18, 'TN': 126, 'precision': 0.26666666666666666, 'recall': 0.18181818181818182, 'f1-score': 0.21621621621621623}
# 知母 {'TP': 4, 'FP': 14, 'FN': 19, 'TN': 122, 'precision': 0.2222222222222222, 'recall': 0.17391304347826086, 'f1-score': 0.1951219512195122}
# 梔子 {'TP': 2, 'FP': 5, 'FN': 24, 'TN': 128, 'precision': 0.2857142857142857, 'recall': 0.07692307692307693, 'f1-score': 0.12121212121212123}
# 天花粉 {'TP': 0, 'FP': 2, 'FN': 4, 'TN': 153, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 夏枯草 {'TP': 0, 'FP': 14, 'FN': 5, 'TN': 140, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 決明子 {'TP': 0, 'FP': 12, 'FN': 2, 'TN': 145, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 生地 {'TP': 6, 'FP': 19, 'FN': 14, 'TN': 120, 'precision': 0.24, 'recall': 0.3, 'f1-score': 0.2666666666666666}
# 牡丹皮 {'TP': 0, 'FP': 1, 'FN': 1, 'TN': 157, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 連翹 {'TP': 0, 'FP': 16, 'FN': 1, 'TN': 142, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 射干 {'TP': 0, 'FP': 6, 'FN': 6, 'TN': 147, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 黃連 {'TP': 5, 'FP': 30, 'FN': 23, 'TN': 101, 'precision': 0.14285714285714285, 'recall': 0.17857142857142858, 'f1-score': 0.15873015873015875}
# 黃芩 {'TP': 33, 'FP': 37, 'FN': 34, 'TN': 55, 'precision': 0.4714285714285714, 'recall': 0.4925373134328358, 'f1-score': 0.4817518248175182}
# 黃柏 {'TP': 0, 'FP': 12, 'FN': 10, 'TN': 137, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 龍膽草 {'TP': 10, 'FP': 40, 'FN': 15, 'TN': 94, 'precision': 0.2, 'recall': 0.4, 'f1-score': 0.26666666666666666}
# 大黃 {'TP': 14, 'FP': 36, 'FN': 8, 'TN': 101, 'precision': 0.28, 'recall': 0.6363636363636364, 'f1-score': 0.3888888888888889}
# 芒硝 {'TP': 2, 'FP': 24, 'FN': 3, 'TN': 130, 'precision': 0.07692307692307693, 'recall': 0.4, 'f1-score': 0.12903225806451613}
# 防己 {'TP': 7, 'FP': 11, 'FN': 15, 'TN': 126, 'precision': 0.3888888888888889, 'recall': 0.3181818181818182, 'f1-score': 0.35000000000000003}
# 秦艽 {'TP': 1, 'FP': 21, 'FN': 2, 'TN': 135, 'precision': 0.045454545454545456, 'recall': 0.3333333333333333, 'f1-score': 0.08}
# 絡石藤 {'TP': 1, 'FP': 4, 'FN': 5, 'TN': 149, 'precision': 0.2, 'recall': 0.16666666666666666, 'f1-score': 0.1818181818181818}
# 蒼朮 {'TP': 1, 'FP': 6, 'FN': 14, 'TN': 138, 'precision': 0.14285714285714285, 'recall': 0.06666666666666667, 'f1-score': 0.09090909090909091}
# 草果 {'TP': 0, 'FP': 10, 'FN': 1, 'TN': 148, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 茯苓 {'TP': 37, 'FP': 67, 'FN': 24, 'TN': 31, 'precision': 0.3557692307692308, 'recall': 0.6065573770491803, 'f1-score': 0.4484848484848485}
# 豬苓 {'TP': 9, 'FP': 45, 'FN': 9, 'TN': 96, 'precision': 0.16666666666666666, 'recall': 0.5, 'f1-score': 0.25}
# 薏苡仁 {'TP': 0, 'FP': 20, 'FN': 2, 'TN': 137, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 海金砂 {'TP': 0, 'FP': 12, 'FN': 2, 'TN': 145, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 澤瀉 {'TP': 22, 'FP': 12, 'FN': 50, 'TN': 75, 'precision': 0.6470588235294118, 'recall': 0.3055555555555556, 'f1-score': 0.41509433962264153}
# 車前子 {'TP': 0, 'FP': 9, 'FN': 2, 'TN': 148, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 滑石 {'TP': 0, 'FP': 5, 'FN': 5, 'TN': 149, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 木通 {'TP': 7, 'FP': 49, 'FN': 8, 'TN': 95, 'precision': 0.125, 'recall': 0.4666666666666667, 'f1-score': 0.19718309859154928}
# 通草 {'TP': 1, 'FP': 4, 'FN': 3, 'TN': 151, 'precision': 0.2, 'recall': 0.25, 'f1-score': 0.22222222222222224}
# 赤小豆 {'TP': 0, 'FP': 5, 'FN': 2, 'TN': 152, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 燈心草 {'TP': 1, 'FP': 5, 'FN': 3, 'TN': 150, 'precision': 0.16666666666666666, 'recall': 0.25, 'f1-score': 0.2}
# 乾薑 {'TP': 4, 'FP': 4, 'FN': 42, 'TN': 109, 'precision': 0.5, 'recall': 0.08695652173913043, 'f1-score': 0.14814814814814817}
# 附子 {'TP': 51, 'FP': 46, 'FN': 27, 'TN': 35, 'precision': 0.5257731958762887, 'recall': 0.6538461538461539, 'f1-score': 0.5828571428571429}
# 吳茱萸 {'TP': 6, 'FP': 15, 'FN': 17, 'TN': 121, 'precision': 0.2857142857142857, 'recall': 0.2608695652173913, 'f1-score': 0.2727272727272727}
# 枳實 {'TP': 10, 'FP': 20, 'FN': 12, 'TN': 117, 'precision': 0.3333333333333333, 'recall': 0.45454545454545453, 'f1-score': 0.3846153846153846}
# 烏藥 {'TP': 10, 'FP': 26, 'FN': 18, 'TN': 105, 'precision': 0.2777777777777778, 'recall': 0.35714285714285715, 'f1-score': 0.31250000000000006}
# 厚朴 {'TP': 7, 'FP': 29, 'FN': 16, 'TN': 107, 'precision': 0.19444444444444445, 'recall': 0.30434782608695654, 'f1-score': 0.23728813559322037}
# 大腹皮 {'TP': 0, 'FP': 13, 'FN': 2, 'TN': 144, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 青皮 {'TP': 0, 'FP': 15, 'FN': 6, 'TN': 138, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 薤白 {'TP': 0, 'FP': 18, 'FN': 2, 'TN': 139, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 麥芽 {'TP': 4, 'FP': 24, 'FN': 9, 'TN': 122, 'precision': 0.14285714285714285, 'recall': 0.3076923076923077, 'f1-score': 0.1951219512195122}
# 側柏葉 {'TP': 3, 'FP': 14, 'FN': 6, 'TN': 136, 'precision': 0.17647058823529413, 'recall': 0.3333333333333333, 'f1-score': 0.23076923076923078}
# 槐花 {'TP': 0, 'FP': 37, 'FN': 3, 'TN': 119, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 三七 {'TP': 0, 'FP': 9, 'FN': 4, 'TN': 146, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 茜草 {'TP': 8, 'FP': 27, 'FN': 17, 'TN': 107, 'precision': 0.22857142857142856, 'recall': 0.32, 'f1-score': 0.26666666666666666}
# 川芎 {'TP': 16, 'FP': 38, 'FN': 29, 'TN': 76, 'precision': 0.2962962962962963, 'recall': 0.35555555555555557, 'f1-score': 0.3232323232323232}
# 乳香 {'TP': 0, 'FP': 7, 'FN': 2, 'TN': 150, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 延胡索 {'TP': 0, 'FP': 11, 'FN': 0, 'TN': 148, 'precision': 0.0, 'recall': 0, 'f1-score': 0}
# 鬱金 {'TP': 12, 'FP': 31, 'FN': 15, 'TN': 101, 'precision': 0.27906976744186046, 'recall': 0.4444444444444444, 'f1-score': 0.34285714285714286}
# 紅花 {'TP': 0, 'FP': 4, 'FN': 1, 'TN': 154, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 桃仁 {'TP': 2, 'FP': 20, 'FN': 6, 'TN': 131, 'precision': 0.09090909090909091, 'recall': 0.25, 'f1-score': 0.13333333333333333}
# 牛膝 {'TP': 2, 'FP': 13, 'FN': 8, 'TN': 136, 'precision': 0.13333333333333333, 'recall': 0.2, 'f1-score': 0.16}
# 半夏 {'TP': 36, 'FP': 70, 'FN': 13, 'TN': 40, 'precision': 0.33962264150943394, 'recall': 0.7346938775510204, 'f1-score': 0.46451612903225803}
# 白附子 {'TP': 0, 'FP': 12, 'FN': 1, 'TN': 146, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 桔梗 {'TP': 4, 'FP': 16, 'FN': 4, 'TN': 135, 'precision': 0.2, 'recall': 0.5, 'f1-score': 0.28571428571428575}
# 旋覆花 {'TP': 4, 'FP': 18, 'FN': 10, 'TN': 127, 'precision': 0.18181818181818182, 'recall': 0.2857142857142857, 'f1-score': 0.2222222222222222}
# 瓜蔞 {'TP': 0, 'FP': 6, 'FN': 1, 'TN': 152, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 海藻 {'TP': 1, 'FP': 9, 'FN': 3, 'TN': 146, 'precision': 0.1, 'recall': 0.25, 'f1-score': 0.14285714285714288}
# 杏仁 {'TP': 1, 'FP': 28, 'FN': 11, 'TN': 119, 'precision': 0.034482758620689655, 'recall': 0.08333333333333333, 'f1-score': 0.04878048780487805}
# 紫菀 {'TP': 0, 'FP': 12, 'FN': 3, 'TN': 144, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 龍骨 {'TP': 6, 'FP': 43, 'FN': 3, 'TN': 107, 'precision': 0.12244897959183673, 'recall': 0.6666666666666666, 'f1-score': 0.20689655172413793}
# 牡蠣 {'TP': 9, 'FP': 42, 'FN': 16, 'TN': 92, 'precision': 0.17647058823529413, 'recall': 0.36, 'f1-score': 0.2368421052631579}
# 酸棗仁 {'TP': 4, 'FP': 35, 'FN': 7, 'TN': 113, 'precision': 0.10256410256410256, 'recall': 0.36363636363636365, 'f1-score': 0.16}
# 遠志 {'TP': 3, 'FP': 34, 'FN': 5, 'TN': 117, 'precision': 0.08108108108108109, 'recall': 0.375, 'f1-score': 0.13333333333333333}
# 小麥 {'TP': 2, 'FP': 47, 'FN': 2, 'TN': 108, 'precision': 0.04081632653061224, 'recall': 0.5, 'f1-score': 0.07547169811320753}
# 代赭石 {'TP': 4, 'FP': 16, 'FN': 13, 'TN': 126, 'precision': 0.2, 'recall': 0.23529411764705882, 'f1-score': 0.2162162162162162}
# 黃耆 {'TP': 5, 'FP': 46, 'FN': 12, 'TN': 96, 'precision': 0.09803921568627451, 'recall': 0.29411764705882354, 'f1-score': 0.14705882352941177}
# 白朮 {'TP': 20, 'FP': 31, 'FN': 24, 'TN': 84, 'precision': 0.39215686274509803, 'recall': 0.45454545454545453, 'f1-score': 0.4210526315789474}
# 大棗 {'TP': 9, 'FP': 26, 'FN': 18, 'TN': 106, 'precision': 0.2571428571428571, 'recall': 0.3333333333333333, 'f1-score': 0.2903225806451613}
# 甘草 {'TP': 27, 'FP': 20, 'FN': 62, 'TN': 50, 'precision': 0.574468085106383, 'recall': 0.30337078651685395, 'f1-score': 0.39705882352941174}
# 巴戟天 {'TP': 4, 'FP': 24, 'FN': 12, 'TN': 119, 'precision': 0.14285714285714285, 'recall': 0.25, 'f1-score': 0.18181818181818182}
# 補骨脂 {'TP': 16, 'FP': 37, 'FN': 28, 'TN': 78, 'precision': 0.3018867924528302, 'recall': 0.36363636363636365, 'f1-score': 0.32989690721649484}
# 益智仁 {'TP': 1, 'FP': 8, 'FN': 1, 'TN': 149, 'precision': 0.1111111111111111, 'recall': 0.5, 'f1-score': 0.1818181818181818}
# 陽起石 {'TP': 4, 'FP': 41, 'FN': 4, 'TN': 110, 'precision': 0.08888888888888889, 'recall': 0.5, 'f1-score': 0.1509433962264151}
# 續斷 {'TP': 1, 'FP': 84, 'FN': 3, 'TN': 71, 'precision': 0.011764705882352941, 'recall': 0.25, 'f1-score': 0.02247191011235955}
# 杜仲 {'TP': 2, 'FP': 32, 'FN': 1, 'TN': 124, 'precision': 0.058823529411764705, 'recall': 0.6666666666666666, 'f1-score': 0.10810810810810811}
# 何首烏 {'TP': 1, 'FP': 10, 'FN': 5, 'TN': 143, 'precision': 0.09090909090909091, 'recall': 0.16666666666666666, 'f1-score': 0.11764705882352942}
# 當歸 {'TP': 35, 'FP': 49, 'FN': 17, 'TN': 58, 'precision': 0.4166666666666667, 'recall': 0.6730769230769231, 'f1-score': 0.5147058823529412}
# 白芍 {'TP': 57, 'FP': 33, 'FN': 39, 'TN': 30, 'precision': 0.6333333333333333, 'recall': 0.59375, 'f1-score': 0.6129032258064516}
# 阿膠 {'TP': 6, 'FP': 46, 'FN': 11, 'TN': 96, 'precision': 0.11538461538461539, 'recall': 0.35294117647058826, 'f1-score': 0.1739130434782609}
# 西洋參 {'TP': 0, 'FP': 30, 'FN': 2, 'TN': 127, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 龜板 {'TP': 3, 'FP': 21, 'FN': 8, 'TN': 127, 'precision': 0.125, 'recall': 0.2727272727272727, 'f1-score': 0.17142857142857143}
# 鱉甲 {'TP': 6, 'FP': 55, 'FN': 6, 'TN': 92, 'precision': 0.09836065573770492, 'recall': 0.5, 'f1-score': 0.1643835616438356}
# 山茱萸 {'TP': 0, 'FP': 23, 'FN': 2, 'TN': 134, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 覆盆子 {'TP': 1, 'FP': 42, 'FN': 3, 'TN': 113, 'precision': 0.023255813953488372, 'recall': 0.25, 'f1-score': 0.0425531914893617}
# 五味子 {'TP': 1, 'FP': 19, 'FN': 8, 'TN': 131, 'precision': 0.05, 'recall': 0.1111111111111111, 'f1-score': 0.06896551724137932}
# 烏梅 {'TP': 0, 'FP': 36, 'FN': 3, 'TN': 120, 'precision': 0.0, 'recall': 0.0, 'f1-score': 0}
# 五倍子 {'TP': 1, 'FP': 23, 'FN': 2, 'TN': 133, 'precision': 0.041666666666666664, 'recall': 0.3333333333333333, 'f1-score': 0.07407407407407407}
# 炙甘草 {'TP': 59, 'FP': 42, 'FN': 34, 'TN': 24, 'precision': 0.5841584158415841, 'recall': 0.6344086021505376, 'f1-score': 0.6082474226804123}
# overall {'TP': 743, 'FP': 2357, 'FN': 1135, 'TN': 11983, 'precision': 0.23967741935483872, 'recall': 0.39563365282215124, 'f1-score': 0.29851345922057054}

# %% [markdown]
# # 8. Result Saving
#
# Export the evaluation metrics of training and validation data set in csv format.

# %%
# Create a DataFrame to record f1 score, TP/FP/TN/FN of each medicine of training set
train_f1_df = pd.DataFrame([(key, val['f1-score'], val['precision'], val['recall'], 
                           val['TP'], val['FP'], val['TN'], val['FN']) for key, val in TrainMedicineDictioanry.items()], 
                         columns=['medicine', 'f1-score','precision', 'recall', 'TP', 'FP', 'TN', 'FN']
                        )

# Setup the path to save the result
file_path = "./result/" + ModelNum

# Exporting the DataFrame to csv file
myutil.df_to_csv(train_f1_df, save_path=file_path, file_prefix='train_f1')

# Create a DataFrame to record f1 score, TP/FP/TN/FN of each medicine for validation set
val_f1_df = pd.DataFrame([(key, val['f1-score'], val['precision'], val['recall'], 
                           val['TP'], val['FP'], val['TN'], val['FN']) for key, val in ValMedicineDictioanry.items()], 
                         columns=['medicine', 'f1-score','precision', 'recall', 'TP', 'FP', 'TN', 'FN']
                        )
# Setup the path to save the result
file_path = "./result/" + ModelNum

# Exporting the DataFrame to csv file
myutil.df_to_csv(val_f1_df, save_path=file_path, file_prefix='val_f1')
# Out:
# train_f1 saved to ./result/[16]_0_UseWeight/train_f1.csv
# val_f1 saved to ./result/[16]_0_UseWeight/val_f1.csv

# %% [markdown]
# # 9. Model Saving
#
# save the model in .pb format by `tensorflow.keras.Model.save`

# %%
model.save(file_path)
# Out:
# INFO:tensorflow:Assets written to: ./result/[16]_0_UseWeight\assets
